# %%
from langchain_community.utilities.sql_database import SQLDatabase
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from config.llm import llm

# 1. Establish your database connection via LangChain wrapper
db = SQLDatabase.from_uri("sqlite:///Chinook.db")

# 2. Initialize LLM supporting tool-calling

# 3. Create the Toolkit
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

# 4. Extract individual tools to feed into your agent workflow
tools = toolkit.get_tools()

# Verify the available inbuilt tools
for tool in tools:
    print(f"Name: {tool.name} | Description: {tool.description}")
# Out:
# Name: sql_db_query | Description: Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields....
# Name: sql_db_schema | Description: Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3...
# Name: sql_db_list_tables | Description: Input is an empty string, output is a comma-separated list of tables in the database....
# Name: sql_db_query_checker | Description: Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!...

# %%
from graph.workflow import analyst_bot

question = "who are the top 3 most selling artists?"
response = analyst_bot.invoke({"question": question})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 from graph.workflow import analyst_bot
#       2
#       3 question = "who are the top 3 most selling artists?"
# ----> 4 response = analyst_bot.invoke({"question": question})
#
# File /mnt/e/AI Data Analyst Project/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
# ...
